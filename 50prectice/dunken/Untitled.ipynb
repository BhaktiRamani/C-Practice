# %%
str_input=input("enter strings")

int_input=int(input("enter a integrer"))
def str_to_int(str_input):
    x=int(str_input)
    print(x)
    print(type(x))
def int_to_str(int_input):

    y=str(int_input)
    print(y)
    print(type(y))
str_to_int(str_input)
int_to_str(int_input)
#print(type(str_input))


#print(type(int_input))
# Out:
# 2
# <class 'int'>
# 3
# <class 'str'>
