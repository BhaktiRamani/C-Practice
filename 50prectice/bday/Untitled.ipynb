# %%
import datetime

today = datetime.date.today().strftime("%d%m")

#x = print("date of today is  " ,today)

#z=str(x)
#print(type(z))


i=0
while i<10:
    x = print("date of today is  " ,today)
    z=str(x)
    list1=["jenisha","bhakti"]
    list2=["2707","2708"]
    y=list2[i]

    if z==y:
        print("today is " + list1[i] + " bday")
    
    else:
        print("no ones bday")
    i=i+1
# Out:
# date of today is   2707
# no ones bday
# date of today is   2707
# no ones bday
# date of today is   2707
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\bhakt\All Data\50prectice\bday\Untitled.ipynb Cell 1 in <cell line: 12>()
#      <a href='vscode-notebook-cell:/c%3A/Users/bhakt/All%20Data/50prectice/bday/Untitled.ipynb#ch0000007?line=14'>15</a> list1=["jenisha","bhakti"]
#      <a href='vscode-notebook-cell:/c%3A/Users/bhakt/All%20Data/50prectice/bday/Untitled.ipynb#ch0000007?line=15'>16</a> list2=["2707","2708"]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/bhakt/All%20Data/50prectice/bday/Untitled.ipynb#ch0000007?line=16'>17</a> y=list2[i]
#      <a href='vscode-notebook-cell:/c%3A/Users/bhakt/All%20Data/50prectice/bday/Untitled.ipynb#ch0000007?line=18'>19</a> if z==y:
# ...

# %%
import re 
import datetime
today=datetime.date.today()
x=print(today)
list=["x"]

split=re.split(r"\D",x,maxsplit=3)
print(split)
# Out:
# 2022-07-27
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\bhakt\All Data\50prectice\bday\Untitled.ipynb Cell 4 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/bhakt/All%20Data/50prectice/bday/Untitled.ipynb#ch0000011?line=3'>4</a> x=print(today)
#       <a href='vscode-notebook-cell:/c%3A/Users/bhakt/All%20Data/50prectice/bday/Untitled.ipynb#ch0000011?line=4'>5</a> list=["x"]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/bhakt/All%20Data/50prectice/bday/Untitled.ipynb#ch0000011?line=6'>7</a> split=re.split(r"\D",x,maxsplit=3)
#       <a href='vscode-notebook-cell:/c%3A/Users/bhakt/All%20Data/50prectice/bday/Untitled.ipynb#ch0000011?line=7'>8</a> print(split)
#
# File c:\Users\bhakt\AppData\Local\Programs\Python\Python39\lib\re.py:231, in split(pattern, string, maxsplit, flags)
#     223 def split(pattern, string, maxsplit=0, flags=0):
# ...

# %%
i=0
while i<10:
    x=["3490"]
    list1=["jenisha","bhakti"]
    list2=["3490","2707"]
    y=list2[i]
    #print(y)

    if x[i]==y:
        print("today is " + list1[i] + " bday")
    
    else:
        print("no ones bday")
    i=i+1
# Out:
# 3490
# today is jenisha bday
# 2707
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\bhakt\All Data\50prectice\bday\Untitled.ipynb Cell 3 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/bhakt/All%20Data/50prectice/bday/Untitled.ipynb#ch0000017?line=5'>6</a> y=list2[i]
#       <a href='vscode-notebook-cell:/c%3A/Users/bhakt/All%20Data/50prectice/bday/Untitled.ipynb#ch0000017?line=6'>7</a> print(y)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/bhakt/All%20Data/50prectice/bday/Untitled.ipynb#ch0000017?line=8'>9</a> if x[i]==y:
#      <a href='vscode-notebook-cell:/c%3A/Users/bhakt/All%20Data/50prectice/bday/Untitled.ipynb#ch0000017?line=9'>10</a>     print("today is " + list1[i] + " bday")
#      <a href='vscode-notebook-cell:/c%3A/Users/bhakt/All%20Data/50prectice/bday/Untitled.ipynb#ch0000017?line=11'>12</a> else:
#
# ...
