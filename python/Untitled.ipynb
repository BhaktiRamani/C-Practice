# %%
list=[0,1,2,3,4,5]
for i in list:
    print(list[i]**2)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25

# %%
# !pip install sklearn
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the 'C:\Users\bhakt\All Data\main-env\Scripts\python.exe -m pip install --upgrade pip' command.
