# %%
import schedule
import time 
def heeloo():
    print("hello how are you")

schedule.every(5).seconds.do(heeloo)
while True:
    schedule.run_pending()
    time.sleep(1)
# Out:
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 8>()
#       7 while True:
#       8     schedule.run_pending()
# ----> 9     time.sleep(1)
#
# KeyboardInterrupt:
