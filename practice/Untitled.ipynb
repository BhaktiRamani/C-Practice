# %%
board=["1","2","3",
       "4","5","6",
       "7","8","9"]
start_the_stupid_game="True"


def bloody_board(board):
    print(board[0] + "|" + board[1] + "|" + board[2])
    print("_ _ _ ")
    print(board[3] + "|" + board[4] + "|" + board[5] )
    print("_ _ _ ")
    print(board[6] + "|" + board[7] + "|" + board[8] )
bloody_board(board)

player1=input("player 1 choose x or o")

print("player1 is :",player1)


player2=input("choose alternative of player1")
print("player2 is :",player2)



def stupid_input_from_stupid_user(board):
    
    inp1=int(input("player 1 enter a place from 1 to 9"))
    
    
    if inp1 >= 1 and inp1<=9 and board[inp1-1]=="1":
        board[inp1-1]=player1
    if inp1 >= 1 and inp1<=9 and board[inp1-1]=="2":
        board[inp1-1]=player1
    if inp1 >= 1 and inp1<=9 and board[inp1-1]=="3":
        board[inp1-1]=player1
    if inp1 >= 1 and inp1<=9 and board[inp1-1]=="4":
        board[inp1-1]=player1
    if inp1 >= 1 and inp1<=9 and board[inp1-1]=="5":
        board[inp1-1]=player1
    if inp1 >= 1 and inp1<=9 and board[inp1-1]=="6":
        board[inp1-1]=player1
    if inp1 >= 1 and inp1<=9 and board[inp1-1]=="7":
        board[inp1-1]=player1
    if inp1 >= 1 and inp1<=9 and board[inp1-1]=="8":
        board[inp1-1]=player1
    if inp1 >= 1 and inp1<=9 and board[inp1-1]=="9":
        board[inp1-1]=player1
    
    
    inp2=int(input("player 2 enter a place from 1 to 9"))

                   
                   
    if inp2 >= 1 and inp2<=9 and board[inp2-1]=="1":
        board[inp2-1]=player2
    if inp2 >= 1 and inp2<=9 and board[inp2-1]=="2":
        board[inp2-1]=player2
    if inp2 >= 1 and inp2<=9 and board[inp2-1]=="3":
        board[inp2-1]=player2
    if inp2 >= 1 and inp2<=9 and board[inp2-1]=="4":
        board[inp2-1]=player2
    if inp2 >= 1 and inp2<=9 and board[inp2-1]=="5":
        board[inp2-1]=player2
    if inp2 >= 1 and inp2<=9 and board[inp2-1]=="6":
        board[inp2-1]=player2
    if inp2 >= 1 and inp2<=9 and board[inp2-1]=="7":
        board[inp2-1]=player2
    if inp2 >= 1 and inp2<=9 and board[inp2-1]=="8":
        board[inp2-1]=player2
    if inp2 >= 1 and inp2<=9 and board[inp2-1]=="9":
        board[inp2-1]=player2
    
    
                   
stupid_input_from_stupid_user(board)

def check_progress():
    

    while start_the_stupid_game:
        bloody_board(board)
        stupid_input_from_stupid_user(board)
        if board[0]=="x" and board[1]=="x" and board[2]=="x":
            print("player1 wins")
            printboard(board)
            break
        if board[3]=="x" and board[4]=="x" and board[5]=="x":
            print("player1 wins")
            printboard(board)
            break
        if board[6]=="x" and board[7]=="x" and board[8]=="x":
            print("player1 wins")
            printboard(board)
            break
        if board[0]=="x" and board[3]=="x" and board[6]=="x":
            print("player1 wins")
            printboard(board)
            break
        if board[1]=="x" and board[4]=="x" and board[7]=="x":
            print("player1 wins")
            printboard(board)
            break
        if board[2]=="x" and board[5]=="x" and board[8]=="x":
            print("player1 wins")
            printboard(board)
            break
        if board[0]=="x" and board[4]=="x" and board[8]=="x":
            print("player1 wins")
            printboard(board)
            break
        if board[2]=="x" and board[4]=="x" and board[6]=="x":
            print("player1 wins")
            printboard(board)
            break
    
        
        if board[0]=="o" and board[1]=="o" and board[2]=="o":
            print("player2 wins")
            printboard(board)
            break
        if board[3]=="o" and board[4]=="o" and board[5]=="o":
            print("player2 wins")
            printboard(board)
            break
        if board[6]=="o" and board[7]=="o" and board[8]=="o":
            print("player2 wins")
            printboard(board)
            break
        if board[0]=="o" and board[3]=="o" and board[6]=="o":
            print("player2 wins")
            printboard(board)
            break
        if board[1]=="o" and board[4]=="o" and board[7]=="o":
            print("player2 wins")
            printboard(board)
            break
        if board[2]=="o" and board[5]=="o" and board[8]=="o":
            print("player2 wins")
            printboard(board)
            break
        if board[0]=="o" and board[4]=="o" and board[8]=="o":
            print("player2 wins")
            printboard(board)
            break
        if board[2]=="o" and board[4]=="o" and board[6]=="o":
            print("player2 wins")
            printboard(board)
            break
            
    
check_progress()
while True:
    print("continue or not")
    user_input=input()
    if user_input=="yes":
        board=["1","2","3",
               "4","5","6",
               "7","8","9"]
        bloody_board(board)

        player1=input(" player 1 choose x or o")

        print("player1 is :",player1)

        player2=input("choose alternative of player1")
    
    
        print("player2 is :",player2)
    
        stupid_input_from_stupid_user(board)
        check_progress()
    else:
        print("get lost")
    False
# Out:
# 1|2|3
# _ _ _
# 4|5|6
# _ _ _
# 7|8|9
# player 1 choose x or o o
# player1 is : o
# choose alternative of player1 x
# player2 is : x
# player 1 enter a place from 1 to 9 2
# player 2 enter a place from 1 to 9 4
# 1|o|3
# _ _ _
# x|5|6
# _ _ _
# 7|8|9
# player 1 enter a place from 1 to 9 1
# player 2 enter a place from 1 to 9 5
# o|o|3
# _ _ _
# x|x|6
# _ _ _
# 7|8|9
# player 1 enter a place from 1 to 9 3
# player 2 enter a place from 1 to 9 8
# player2 wins
# o|o|o
# _ _ _
# x|x|6
# _ _ _
# 7|x|9
# continue or not
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [59], in <cell line: 153>()
#     152 while True:
#     153     print("continue or not")
# --> 154     user_input=input()
#     155     if user_input=="yes":
#     156         board=["1","2","3",
#     157                "4","5","6",
#     158                "7","8","9"]
#
# ...

# %%
inp1=int(input("player 1 enter a place from 1 to 9"))
    
    
    #if inp1 >= 1 and inp1<=9 and board[inp1-1]=="1":
        #board[inp1-1]=player1
for i in range(9):
    if inp1>=1 and inp1<=9 and board[inp1-1]==i:
        print('hey')
# Out:
# player 1 enter a place from 1 to 9 2

# %%
list=[1,2,3,4]
for i in range(9):
    x=int(input())
    
    if list[x]==int(i):
        print("hirhf")
# Out:
#  2
#  1
#  3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [92], in <cell line: 2>()
#       1 list=[1,2,3,4]
#       2 for i in range(9):
# ----> 3     x=int(input())
#       5     if list[x]==i:
#       6         print("hirhf")
#
# File ~\All Data\main-env\lib\site-packages\ipykernel\kernelbase.py:1161, in Kernel.raw_input(self, prompt)
#    1157 if not self._allow_stdin:
#    1158     raise StdinNotImplementedError(
#    1159         "raw_input was called, but this frontend does not support input requests."
#    1160     )
# -> 1161 return self._input_request(
#    1162     str(prompt),
#    1163     self._parent_ident["shell"],
#    1164     self.get_parent("shell"),
#    1165     password=False,
#    1166 )
#
# File ~\All Data\main-env\lib\site-packages\ipykernel\kernelbase.py:1205, in Kernel._input_request(self, prompt, ident, parent, password)
# ...

# %%
list=[1,2,3,4]
for i in range(9):
    x=int(input())
    
    if list[x]==int():
        print("hirhf")
