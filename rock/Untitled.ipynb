# %%
print(" welcome to rock paper siccor game")
play1_score = 0
play2_score = 0
n=0
def check():
    if play1_score<=play2_score:
        print("player 2 wins the game")
    elif play2_score<=play1_score:
        print("player 1 wins the game")
    elif play1_score==play2_score:
        print("its a tie")
while n<6:
    play1=input("play 1 enter rock paper or scissors" )
    play2=input("play 2 enter rock paper or scissors")
    if play1.lower() =='rock' and play2.lower()=="rock":
        print("its tie")
        n+=1
    if play1.lower()=='paper' and play2.lower()=="paper":
        print("its tie")
        n+=1
    if play1.lower()=='scissors' and play2.lower()=="scissors":
        print("its tie")
        n+=1
        
    if play1.lower()=='rock' and play2.lower()=="paper":
        print("play 2 wins")
        play2_score += 1
        n+=1
    if play1.lower()=='paper' and play2.lower()=="rock":
        print("play 1 wins")
        play1_score +=1
        n+=1
    if play1.lower()=='rock' and play2.lower()=="scissors":
        print("play 1 wins")
        play1_score += 1
        n+=1
    if play1.lower()=='scissors' and play2.lower()=="rock":
        print("play 1 wins")
        play1_score +=1
        n+=1
    if play1.lower()=='paper' and play2.lower()=="scissors":
        print("play 2 wins")
        play2_score +=1
        n+=1
    if play1.lower()=="scissors" and play2.lower()=="paper":
        print("play 1 wins")
        play1_score +=1
        n+=1
check()

   
print("score of player1 is : " ,play1_score)
print("score of player2 is : ", play2_score)
# Out:
#  welcome to rock paper siccor game
# play 1 enter rock paper or scissors rock
# play 2 enter rock paper or scissors rock
# its tie
# play 1 enter rock paper or scissors rock
# play 2 enter rock paper or scissors scissors
# play 1 wins
# play 1 enter rock paper or scissors rock
# play 2 enter rock paper or scissors paper
# play 2 wins
# play 1 enter rock paper or scissors rock
# play 2 enter rock paper or scissors scissors
# play 1 wins
# play 1 enter rock paper or scissors paper
# play 2 enter rock paper or scissors scissors
# play 2 wins
# play 1 enter rock paper or scissors rock
# play 2 enter rock paper or scissors rock
# its tie
# player 2 wins the game
# score of player1 is :  2
# score of player2 is :  2

# %%
def check():
    if play1_score<=play2_score:
        print("player 1 wins the game")
    elif play2_score<=play1_score:
        print("player 2 wins the game")
    else:
        print("its a tie")

# %%
# rock paper scissor with computer
import random
option=["rock","paper","scissor"]
user1_score = 0
comp_score = 0
while True :
    user_inp=int(input("input 0 for rock, 1 for paper, 2 for scissor"))
    rand_var=random.randint(0,2)
    comp_pick=option[rand_var]
    print("random variable is " ,rand_var)
    print("computer picked" ,comp_pick)
    user1 = print("you picked" ,option[user_inp])
        
    if user1 =='rock' and comp_pick=="rock":
        print("its tie")
    if user1 =='paper' and comp_pick=="paper":
        print("its tie")
    if user1 =='scissor' and comp_pick=="scissor":
        print("its tie")
        
    if user1=='paper' and comp_pick=="rock":
        print("user 1 wins")
        user1_score+=1   
    if user1=='scissor' and comp_pick=="paper":
        print("user 1 wins")
        user1_score+=1 
    if user1=='rock' and comp_pick=="scissor":
        print("user 1 wins")
        user1_score+=1 
        
    if user1=='paper' and comp_pick=="scissor":
        print("computer wins")
        comp_score+=1
    if user1=='rock' and comp_pick=="paper":
        print("computer wins")
        comp_score+=1
    if user1=='scissor' and comp_pick=="paper":
        print("computer wins")
        comp_score+=1

print("your score is  :" ,user1_score)
print("computer's score is : " ,comp_score)
# Out:
# input 0 for rock, 1 for paper, 2 for scissor 0
# random variable is  2
# computer picked scissor
# you picked rock

# %%
x=int(input())
list=["q","e","y"]
print(list[x])
# Out:
#  1
# e
