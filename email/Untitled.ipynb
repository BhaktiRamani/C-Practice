# %%
import smtplib
import ssl
server=smtplib.SMTP_SSL("smtp.gmail.com",465)
server.login("brramani.2002@gmail.com","fhhtojjlnbluzfvc")
server.sendmail("brramani.2002@gmail.com","dhruvirudani@gmail.com","heeeeeeeeeey")
print("email sent")
server.quit()
# Out:
# email sent
# (221,
#  b'2.0.0 closing connection y22-20020a626416000000b0052b798ff60esm6310334pfb.177 - gsmtp')

# %%
import smtplib, ssl

port = 465 
context = ssl.create_default_context()

with smtplib.SMTP_SSL("smtp.gmail.com", port, context=context) as server:
    server.login('brramani.2002@gmail.com','fhhtojjlnbluzfvc')
    server.sendmail('brramani.2002@gmail.com', 'bhakti.ramani2020@gmail.com','heyyyya pada sending email through pythom...hope this works okay bbyeeee')
